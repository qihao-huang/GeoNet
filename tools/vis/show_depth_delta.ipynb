# %%
import numpy as np
import os
import matplotlib as mpl
import matplotlib.pyplot as plt

# %%
base_path = "/userhome/34/h3567721/projects/Depth/GeoNet/predictions/depth_geo_delta_two_stage_lr2"

# %%
tgt_image = np.load(os.path.join(base_path, "tgt_image", "2011_09_26_drive_0027_sync_02_0000000007.npy"))

# %%
src_image_stack = np.load(os.path.join(base_path, "src_image_stack", "2011_09_26_drive_0027_sync_02_0000000007.npy"))

# %%
plt.imshow((src_image_stack[0,:,:,0:3]+1)/2) # t-1

# %%
plt.imshow((tgt_image[0]+1)/2) # t

# %%
plt.imshow((src_image_stack[0,:,:,3:6]+1)/2) # t+1

# %%
bwd_rigid_warp = np.load(os.path.join(base_path, "bwd_rigid_warp", "2011_09_26_drive_0027_sync_02_0000000007.npy"))

# %%
plt.imshow((bwd_rigid_warp[0]+1)/2)

# %%
plt.imshow((bwd_rigid_warp[1]+1)/2)

# %%
delta = np.load(os.path.join(base_path, "delta_xyz", "2011_09_26_drive_0027_sync_02_0000000007.npy"))

# %%
# i=0: 0:3 -> fwd tgt->src_1 , 6:9 -> bwd src_1->tgt
# i=1: 3:6 -> fwd tgt->src_2, 9:12 -> bwd src_2->tgt

# %%
np.min(delta[0,:,:,0:3])
# Out:
# -1.2211244

# %%
np.max(delta[0,:,:,0:3])
# Out:
# 10.964514

# %%
plt.imshow(delta[0,:,:,0]) # delta[0:3][0], fwd tgt->src_1, x

# %%
plt.imshow(delta[0,:,:,1]) # delta[0:3][0], fwd tgt->src_1, y

# %%
plt.imshow(delta[0,:,:,2]) # delta[0:3][0], fwd tgt->src_1, z
